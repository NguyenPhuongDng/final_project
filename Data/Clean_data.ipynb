# %%
import pandas as pd
import numpy as np

# %%
df_full_post = pd.read_csv("Data.csv")
df_full_post['time'] = pd.to_datetime(df_full_post['time'], errors='coerce')

# %%
df_full_post.shape
# Out:
# (300, 53)

# %%
df_full_post.dropna(subset=['reactions'], inplace=True)
df_full_post.dropna(subset=['reaction_count'], inplace=True)
df_full_post.dropna(subset=['shares'], inplace=True)
df_full_post.dropna(subset=['comments'], inplace=True)
df_full_post.dropna(subset=['comments_full'], inplace=True)
df_full_post.dropna(subset=['time'], inplace=True)

# %%
df_full_post["post_text"] = df_full_post["post_text"].str.replace('\n', ' ')

# %%
df_full_post = df_full_post[(df_full_post['time'].dt.year == 2023)&(df_full_post['time'].dt.month.isin([8, 9, 10, 11]))]

# %%
df_full_post.dropna(axis=1, how='all', inplace=True)

# %%
df_full_post = df_full_post.T.drop_duplicates().T

# %%
del df_full_post['text']
del df_full_post['images']
del df_full_post['image_ids']
del df_full_post['images_description']
del df_full_post['fetched_time']
del df_full_post['images_lowquality']

# %%
df_full_post.shape
# Out:
# (165, 29)

# %%
df_full_post.head(10)
# Out:
#   Unnamed: 0          post_id  \
# 0          0  663270455960281
# 1          1  663233825963944
# 2          2  663166792637314
# 3          3  663140965973230
# 4          4  663095489311111
# 5          5  663050329315627
# 6          6  663017269318933
# 7          7  662974212656572
# 8          8  662740356013291
# 9          9  662697726017554
#
#                                            post_text  \
# 0              Thời tới 👇🏻👇🏻  The time has come 👇🏻👇🏻
# 1       muốn người ta sẽ tìm cách ❤️‍🩹  📷: htcuteaaa
# 2  Chỉ người từng trải mới hiểu  Only those who h...
# 3            z học bài mới dô 🤩  📷: trangcaoquocxeng
# 4                                     Ủa tại sao vậy
# 5                                  Lại bảo dễ đi :))
# 6                          hình ảnh tui mỗi sáng =))
# 7                         Thiện style, thiện style 🥲
# 8               Những tấm chiếu mới sao mà hiểu được
# 9              cứ phải gọi là mờ ê mê  📷: lucastaa02
#
#                   original_text                 time     timestamp  \
# 0                 Thời tới 👇🏻👇🏻  2023-11-19 03:19:04  1700320744.0
# 1                           NaN  2023-11-19 02:00:35  1700316035.0
# 2  Chỉ người từng trải mới hiểu  2023-11-18 23:21:21  1700306481.0
# 3                           NaN  2023-11-18 22:17:11  1700302631.0
# 4                           NaN  2023-11-18 20:00:11  1700294411.0
# 5                           NaN  2023-11-18 18:05:08  1700287508.0
# 6                           NaN  2023-11-18 16:30:24  1700281824.0
# 7                           NaN  2023-11-18 14:34:20  1700274860.0
# 8                           NaN  2023-11-18 03:27:54  1700234874.0
# 9                           NaN  2023-11-18 02:00:32  1700229632.0
#
#                                                image  \
# 0                                                NaN
# 1                                                NaN
# 2  https://scontent.fhph3-1.fna.fbcdn.net/v/t39.3...
# 3                                                NaN
# 4  https://m.facebook.com/photo/view_full_size/?f...
# 5  https://scontent.fhph3-1.fna.fbcdn.net/v/t39.3...
# 6                                                NaN
# 7  https://scontent.fhph3-1.fna.fbcdn.net/v/t39.3...
# 8                                                NaN
# 9                                                NaN
#
#                                     image_lowquality  \
# 0  https://scontent.fhph3-1.fna.fbcdn.net/v/t39.3...
# 1  https://scontent.fhph3-1.fna.fbcdn.net/v/t15.5...
# 2  https://scontent.fhph3-1.fna.fbcdn.net/v/t39.3...
# 3  https://scontent.fhph3-1.fna.fbcdn.net/v/t15.5...
# 4  https://scontent.fhph3-1.fna.fbcdn.net/v/t39.3...
# 5  https://scontent.fhph3-1.fna.fbcdn.net/v/t39.3...
# 6  https://scontent.fhph3-1.fna.fbcdn.net/v/t15.5...
# 7  https://scontent.fhph3-1.fna.fbcdn.net/v/t39.3...
# 8  https://scontent.fhph3-1.fna.fbcdn.net/v/t39.3...
# 9  https://scontent.fhph3-1.fna.fbcdn.net/v/t15.5...
#
#                        images_lowquality_description  \
# 0  ["May be an image of text that says '2023 N.Ợ ...
# 1                                             [None]
# 2  ["May be an image of 1 person, phone and text ...
# 3                                             [None]
# 4  ["May be an image of 2 people and text that sa...
# 5  ["May be an image of map and text that says 'H...
# 6                                             [None]
# 7           ['May be an image of 2 people and text']
# 8  ["May be an image of text that says 'Em ơi Dạ ...
# 9                                             [None]
#
#                                                video  ...  \
# 0                                                NaN  ...
# 1  https://scontent.fhph3-1.fna.fbcdn.net/v/t42.1...  ...
# 2                                                NaN  ...
# 3  https://scontent.fhph3-1.fna.fbcdn.net/v/t42.1...  ...
# 4                                                NaN  ...
# 5                                                NaN  ...
# 6  https://scontent.fhph3-1.fna.fbcdn.net/v/t42.1...  ...
# 7                                                NaN  ...
# 8                                                NaN  ...
# 9  https://scontent.fhph3-1.fna.fbcdn.net/v/t42.1...  ...
#
#                                             user_url is_live available  \
# 0  https://facebook.com/if.bluevn?lst=61553203002...   False      True
# 1  https://facebook.com/if.bluevn?lst=61553203002...   False      True
# 2  https://facebook.com/if.bluevn?lst=61553203002...   False      True
# 3  https://facebook.com/if.bluevn?lst=61553203002...   False      True
# 4  https://facebook.com/if.bluevn?lst=61553203002...   False      True
# 5  https://facebook.com/if.bluevn?lst=61553203002...   False      True
# 6  https://facebook.com/if.bluevn?lst=61553203002...   False      True
# 7  https://facebook.com/if.bluevn?lst=61553203002...   False      True
# 8  https://facebook.com/if.bluevn?lst=61553203002...   False      True
# 9  https://facebook.com/if.bluevn?lst=61553203002...   False      True
#
#                                        comments_full  \
# 0  [{'comment_id': '264336822890827', 'comment_ur...
# 1  [{'comment_id': '1300474830621287', 'comment_u...
# 2  [{'comment_id': '366492152610224', 'comment_ur...
# 3  [{'comment_id': '1758530451241943', 'comment_u...
# 4  [{'comment_id': '307708705494834', 'comment_ur...
# 5  [{'comment_id': '1549000372508556', 'comment_u...
# 6  [{'comment_id': '3456255947959932', 'comment_u...
# 7  [{'comment_id': '231249039976637', 'comment_ur...
# 8  [{'comment_id': '228882980081148', 'comment_ur...
# 9  [{'comment_id': '288458620220338', 'comment_ur...
#
#                                             reactors  \
# 0                                                 []
# 1  [{'name': 'Ann Thư', 'link': 'https://facebook...
# 2  [{'name': 'Đạt Em', 'link': 'https://facebook....
# 3  [{'name': 'Thy Wy', 'link': 'https://facebook....
# 4  [{'name': 'Ánh Đan', 'link': 'https://facebook...
# 5  [{'name': 'Nam Bùi', 'link': 'https://facebook...
# 6  [{'name': 'Ngô Hải Đông', 'link': 'https://fac...
# 7  [{'name': 'Kiều Nguyễn Nhã Quân', 'link': 'htt...
# 8  [{'name': 'Ngoc Thy', 'link': 'https://faceboo...
# 9  [{'name': 'Đặng Khánh Đăng', 'link': 'https://...
#
#                                            w3_fb_url  \
# 0  https://www.facebook.com/if.bluevn/posts/66327...
# 1  https://www.facebook.com/if.bluevn/posts/66323...
# 2  https://www.facebook.com/if.bluevn/posts/66316...
# 3  https://www.facebook.com/if.bluevn/posts/66314...
# 4  https://www.facebook.com/if.bluevn/posts/66309...
# 5  https://www.facebook.com/if.bluevn/posts/66305...
# 6  https://www.facebook.com/if.bluevn/posts/66301...
# 7  https://www.facebook.com/if.bluevn/posts/66297...
# 8  https://www.facebook.com/if.bluevn/posts/66274...
# 9  https://www.facebook.com/if.bluevn/posts/66269...
#
#                                            reactions reaction_count  \
# 0      {'like': 74, 'love': 16, 'haha': 1, 'sad': 1}             92
# 1  {'like': 905, 'love': 856, 'haha': 45, 'wow': ...           1854
# 2  {'like': 332, 'love': 7, 'haha': 231, 'wow': 1...            583
# 3  {'like': 1162, 'love': 67, 'haha': 1253, 'wow'...           2720
# 4  {'like': 283, 'love': 6, 'haha': 57, 'care': 2...            355
# 5  {'like': 536, 'love': 5, 'haha': 212, 'wow': 2...            764
# 6   {'like': 177, 'love': 7, 'haha': 267, 'sad': 60}            511
# 7  {'like': 290, 'love': 5, 'haha': 112, 'wow': 1...            411
# 8  {'like': 396, 'love': 3, 'haha': 290, 'wow': 1...            711
# 9  {'like': 657, 'love': 336, 'haha': 216, 'wow':...           1236
#
#            page_id           image_id
# 0  103079981837110  663270412626952.0
# 1  103079981837110                NaN
# 2  103079981837110  663166699303990.0
# 3  103079981837110                NaN
# 4  103079981837110  663095462644447.0
# 5  103079981837110  663050272648966.0
# 6  103079981837110                NaN
# 7  103079981837110  662973929323267.0
# 8  103079981837110  662740029346657.0
# 9  103079981837110                NaN
#
# [10 rows x 29 columns]

# %%
df_full_post["time"] = pd.to_datetime(df_full_post['time'], format='%Y-%m-%d %H:%M:%S')

df_full_post['date_only'] = df_full_post['time'].dt.strftime('%m-%d-%Y')

# %%
df_full_post["time"] = pd.to_datetime(df_full_post['time'], format='%Y-%m-%d %H:%M:%S')

df_full_post['hour_only'] = df_full_post['time'].dt.strftime('%H-%M')

# %%
row_to_drop = df_full_post[df_full_post["date_only"] == "11-19-2023"].index
df_full_post.drop(row_to_drop, inplace=True)

# %%
df_full_post.to_csv("Data_clean.csv")

# %%
df_full_post.columns
# Out:
# Index(['Unnamed: 0', 'post_id', 'post_text', 'original_text', 'time',
#        'timestamp', 'image', 'image_lowquality',
#        'images_lowquality_description', 'video', 'video_id', 'video_thumbnail',
#        'likes', 'comments', 'shares', 'post_url', 'links', 'user_id',
#        'username', 'user_url', 'is_live', 'available', 'comments_full',
#        'reactors', 'w3_fb_url', 'reactions', 'reaction_count', 'page_id',
#        'image_id', 'date_only', 'hour_only'],
#       dtype='object')
